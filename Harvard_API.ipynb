# %%
import pandas as pd
import numpy as np
import requests
import os

# %% [markdown]
# # Project Description

# %% [markdown]
# ### 1.- Defining Variables

# %% [markdown]
# The cell below contains code that searches for an artist using different resources of the Harvard Art Museum API -

# %%
key = "38e8628b-5bf1-40c0-85dd-72c788315a1b"
artist = "Cezanne"

# %% [markdown]
# The cell below will use the title to find an object with the artist name

# %%
r = requests.get(f'https://api.harvardartmuseums.org/object?person={artist}&apikey={key}')
data = r.json()

# %%
# Extract the info and records
info = data['info']
records = data['records']

# %%
data
# Out:
# {'info': {'totalrecordsperquery': 10,
#   'totalrecords': 32,
#   'pages': 4,
#   'page': 1,
#   'next': 'https://api.harvardartmuseums.org/object?person=Cezanne&apikey=38e8628b-5bf1-40c0-85dd-72c788315a1b&page=2',
#   'responsetime': '11 ms'},
#  'records': [{'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Horace Swope Fund',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-02-09',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 1,
#    'totaluniquepageviews': 118,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 7,
#    'rank': 220347,
#    'id': 264367,
#    'state': 'iii',
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '1998-11-01',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 515,
#      'idsid': 20669228,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Kodak EPY',
#      'renditionnumber': '12039',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS12039_dynmc',
#      'alttext': None,
#      'width': 2345,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20669228',
#      'height': 2041}],
#    'worktypes': [{'worktypeid': '290', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 148,
#    'accessionyear': 1942,
#    'standardreferencenumber': 'Ven. 1156, Druick 3',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS12039_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:50:03-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Lithograph',
#    'edition': None,
#    'description': None,
#    'medium': 'Lithograph on off white wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'The Small Bathers',
#    'accessionmethod': 'Purchase',
#    'colors': [{'color': '#fae1e1',
#      'spectrum': '#e76d63',
#      'hue': 'Red',
#      'percent': 0.3996923076923077,
#      'css3': '#ffe4e1'},
#     {'color': '#e1c8c8',
#      'spectrum': '#c15689',
#      'hue': 'Orange',
#      'percent': 0.21343589743589744,
#      'css3': '#d8bfd8'},
#     {'color': '#c8afaf',
#      'spectrum': '#b55592',
#      'hue': 'Red',
#      'percent': 0.13225641025641025,
#      'css3': '#c0c0c0'},
#     {'color': '#7d967d',
#      'spectrum': '#7866ad',
#      'hue': 'Green',
#      'percent': 0.1261025641025641,
#      'css3': '#808080'},
#     {'color': '#969696',
#      'spectrum': '#8761aa',
#      'hue': 'Grey',
#      'percent': 0.06297435897435898,
#      'css3': '#a9a9a9'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.03882051282051282,
#      'css3': '#696969'},
#     {'color': '#324b4b',
#      'spectrum': '#2eb45d',
#      'hue': 'Grey',
#      'percent': 0.02671794871794872,
#      'css3': '#2f4f4f'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1896-1897',
#    'department': 'Department of Prints',
#    'dateend': 1897,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/264367',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': 'M10115',
#    'labeltext': None,
#    'datebegin': 1896,
#    'culture': 'French',
#    'exhibitioncount': 1,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 264367,
#    'techniqueid': 136,
#    'dimensions': 'chine collé: 22.4 x 27.3 cm (8 13/16 x 10 3/4 in.)\r\nsheet: 39.1 x 53.2 cm (15 3/8 x 20 15/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/264367',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of W. G. Russell Allen',
#    'accesslevel': 1,
#    'dateoflastpageview': '2022-11-30',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 58,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 6,
#    'rank': 214832,
#    'id': 264757,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [{'date': '2007-05-21',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 237148,
#      'idsid': 20307260,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV143436',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV143436_dynmc',
#      'alttext': None,
#      'width': 786,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20307260',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '290', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 74,
#    'accessionyear': 1929,
#    'standardreferencenumber': 'Ven. 1158',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 0,
#    'verificationlevel': 2,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV143436_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:50:05-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Lithograph',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'The Artist',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#e1c8c8',
#      'spectrum': '#c15689',
#      'hue': 'Orange',
#      'percent': 0.8726376811594203,
#      'css3': '#d8bfd8'},
#     {'color': '#7d7d64',
#      'spectrum': '#6cbd45',
#      'hue': 'Yellow',
#      'percent': 0.03292753623188406,
#      'css3': '#808080'},
#     {'color': '#64644b',
#      'spectrum': '#59ba4a',
#      'hue': 'Green',
#      'percent': 0.029507246376811593,
#      'css3': '#696969'},
#     {'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.02608695652173913,
#      'css3': '#d2b48c'},
#     {'color': '#96967d',
#      'spectrum': '#8e5ea7',
#      'hue': 'Green',
#      'percent': 0.02289855072463768,
#      'css3': '#808080'},
#     {'color': '#4b4b32',
#      'spectrum': '#4ab851',
#      'hue': 'Green',
#      'percent': 0.015942028985507246,
#      'css3': '#556b2f'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '19th-20th century',
#    'department': 'Department of Prints',
#    'dateend': 0,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/264757',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th-20th century',
#    'objectnumber': 'M4458',
#    'labeltext': None,
#    'datebegin': 0,
#    'culture': 'French',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 264757,
#    'techniqueid': 136,
#    'dimensions': None,
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/264757',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, George R. Nutter Fund',
#    'accesslevel': 1,
#    'dateoflastpageview': '2022-04-20',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 75,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 7,
#    'rank': 221315,
#    'id': 264809,
#    'state': None,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'period': None,
#    'images': [{'date': '2008-02-28',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 292672,
#      'idsid': 20435221,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV178020',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV178020_dynmc',
#      'alttext': None,
#      'width': 769,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20435221',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '290', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 101,
#    'accessionyear': 1946,
#    'standardreferencenumber': 'Ven. 1159',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 0,
#    'verificationlevel': 2,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV178020_dynmc',
#    'titlescount': 2,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:50:05-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Etching',
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'Armand Guillaumin, Hanged',
#    'accessionmethod': 'Purchase',
#    'colors': [{'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.6950595238095238,
#      'css3': '#f5deb3'},
#     {'color': '#c8af7d',
#      'spectrum': '#e9715f',
#      'hue': 'Brown',
#      'percent': 0.20875,
#      'css3': '#d2b48c'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.044583333333333336,
#      'css3': '#bc8f8f'},
#     {'color': '#967d64',
#      'spectrum': '#b65590',
#      'hue': 'Brown',
#      'percent': 0.02630952380952381,
#      'css3': '#808080'},
#     {'color': '#7d644b',
#      'spectrum': '#b25593',
#      'hue': 'Yellow',
#      'percent': 0.014047619047619048,
#      'css3': '#696969'},
#     {'color': '#644b32',
#      'spectrum': '#59ba4a',
#      'hue': 'Brown',
#      'percent': 0.007083333333333333,
#      'css3': '#556b2f'},
#     {'color': '#323219',
#      'spectrum': '#3db657',
#      'hue': 'Brown',
#      'percent': 0.004166666666666667,
#      'css3': '#2f4f4f'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '19th-20th century',
#    'department': 'Department of Prints',
#    'dateend': 0,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/264809',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th-20th century',
#    'objectnumber': 'M12013',
#    'labeltext': None,
#    'datebegin': 0,
#    'culture': 'French',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 264809,
#    'techniqueid': 116,
#    'dimensions': None,
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/264809',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gray Collection of Engravings Fund',
#    'accesslevel': 1,
#    'dateoflastpageview': '2022-12-30',
#    'classificationid': 23,
#    'division': 'European and American Art',
#    'markscount': 2,
#    'publicationcount': 1,
#    'totaluniquepageviews': 107,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 6,
#    'rank': 207612,
#    'id': 273495,
#    'state': 'i',
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2007-05-21',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 237143,
#      'idsid': 20307256,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV143431',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV143431_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20307256',
#      'height': 787}],
#    'worktypes': [{'worktypeid': '290', 'worktype': 'print'}],
#    'imagecount': 1,
#    'totalpageviews': 141,
#    'accessionyear': None,
#    'standardreferencenumber': 'Venturi 1157',
#    'signed': None,
#    'classification': 'Prints',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV143431_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:50:49-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': 'Lithograph',
#    'edition': None,
#    'description': None,
#    'medium': 'Lithograph on off white wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'The Large Bathers',
#    'accessionmethod': None,
#    'colors': [{'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.7496811594202899,
#      'css3': '#f5deb3'},
#     {'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.11652173913043479,
#      'css3': '#d2b48c'},
#     {'color': '#96967d',
#      'spectrum': '#8e5ea7',
#      'hue': 'Green',
#      'percent': 0.07408695652173913,
#      'css3': '#808080'},
#     {'color': '#7d7d64',
#      'spectrum': '#6cbd45',
#      'hue': 'Yellow',
#      'percent': 0.03628985507246377,
#      'css3': '#808080'},
#     {'color': '#64644b',
#      'spectrum': '#59ba4a',
#      'hue': 'Green',
#      'percent': 0.019130434782608695,
#      'css3': '#696969'},
#     {'color': '#4b4b32',
#      'spectrum': '#4ab851',
#      'hue': 'Green',
#      'percent': 0.004289855072463768,
#      'css3': '#556b2f'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1896-c. 1898',
#    'department': 'Department of Prints',
#    'dateend': 1898,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/273495',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': 'G8736',
#    'labeltext': None,
#    'datebegin': 1896,
#    'culture': 'French',
#    'exhibitioncount': 1,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 273495,
#    'techniqueid': 136,
#    'dimensions': 'image: 41 x 50.5 cm (16 1/8 x 19 7/8 in.)\r\nsheet: 48.3 x 63 cm (19 x 24 13/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/273495',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Mr. and Mrs. Joseph Pulitzer, Jr. in honor of Agnes Mongan',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-03-23',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 2,
#    'publicationcount': 23,
#    'totaluniquepageviews': 461,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 5,
#    'rank': 95658,
#    'id': 295701,
#    'state': None,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'period': None,
#    'images': [{'date': None,
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 37851,
#      'idsid': 43183948,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Ektachrome Professional',
#      'renditionnumber': '81563',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:81563_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183948',
#      'height': 672}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 1,
#    'totalpageviews': 605,
#    'accessionyear': 1977,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 4,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:81563_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:24-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Watercolor and graphite on buff paper; verso: graphite',
#    'lendingpermissionlevel': 0,
#    'title': 'Mont Sainte-Victoire (recto and verso)',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.539047619047619,
#      'css3': '#f5deb3'},
#     {'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.19965986394557822,
#      'css3': '#dcdcdc'},
#     {'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.18612244897959185,
#      'css3': '#d2b48c'},
#     {'color': '#96967d',
#      'spectrum': '#8e5ea7',
#      'hue': 'Green',
#      'percent': 0.07231292517006803,
#      'css3': '#808080'},
#     {'color': '#646464',
#      'spectrum': '#7866ad',
#      'hue': 'Grey',
#      'percent': 0.002857142857142857,
#      'css3': '#696969'}],
#    'provenance': 'Eugène Blot (by 1914) (sale, Paris, Hotel Drouot, June 2, 1933, no. 3, pl. 1). [Alfred Daber, Paris (by 1936)]. [Paul Cassirer, Amsterdam]. Erich Maria Remarque, Ascona and New York (by 1952). [Marianne/Walter Feilchenfeldt, Zurich (after 1958)]. [E. V. Thaw & Co., New York]; Mr. and Mrs. Joseph Pulitzer, Jr., January 12, 1968; gift to Fogg, 1977',
#    'groupcount': 0,
#    'dated': '1885-1887',
#    'department': 'Department of Drawings',
#    'dateend': 1887,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/295701',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': '1977.173',
#    'labeltext': None,
#    'datebegin': 1885,
#    'culture': 'French',
#    'exhibitioncount': 8,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 295701,
#    'techniqueid': None,
#    'dimensions': '30.9 x 46.7 cm (12 3/16 x 18 3/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/295701',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of E. V. Thaw',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-02-10',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 0,
#    'totaluniquepageviews': 93,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 3,
#    'rank': 91948,
#    'id': 295934,
#    'state': None,
#    'verificationleveldescription': 'Unchecked. Object information has not been verified for completeness and has not been vetted',
#    'period': None,
#    'images': [{'date': '2005-05-03',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 110069,
#      'idsid': 18744370,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV005429',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV005429_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18744370',
#      'height': 835}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 1,
#    'totalpageviews': 120,
#    'accessionyear': 1974,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 0,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV005429_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:25-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': None,
#    'lendingpermissionlevel': 0,
#    'title': 'Head of a Young Boy',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.9833879781420765,
#      'css3': '#dcdcdc'},
#     {'color': '#c8c8af',
#      'spectrum': '#b55592',
#      'hue': 'Green',
#      'percent': 0.01639344262295082,
#      'css3': '#c0c0c0'},
#     {'color': '#afaf96',
#      'spectrum': '#8e5ea7',
#      'hue': 'Green',
#      'percent': 0.0002185792349726776,
#      'css3': '#a9a9a9'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '19th-20th century',
#    'department': 'Department of Drawings',
#    'dateend': 0,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': 'Imitator of',
#      'culture': 'French',
#      'displayname': 'Imitator of Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/295934',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th-20th century',
#    'objectnumber': '1974.43',
#    'labeltext': None,
#    'datebegin': 0,
#    'culture': 'French',
#    'exhibitioncount': 0,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 295934,
#    'techniqueid': None,
#    'dimensions': None,
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/295934',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Mr. and Mrs. Frederick Deknatel',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-03-09',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 8,
#    'totaluniquepageviews': 291,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 4,
#    'rank': 85276,
#    'id': 296702,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2018-08-20',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491090,
#      'idsid': 457568617,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768154',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768154',
#      'alttext': None,
#      'width': 2218,
#      'publiccaption': 'recto',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457568617',
#      'height': 2550},
#     {'date': '2018-08-20',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491091,
#      'idsid': 457568613,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768155',
#      'displayorder': 2,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768155',
#      'alttext': None,
#      'width': 2221,
#      'publiccaption': 'verso',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457568613',
#      'height': 2550},
#     {'date': '2008-01-10',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 284926,
#      'idsid': 20429323,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'INV172094',
#      'displayorder': 3,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV172094_dynmc',
#      'alttext': None,
#      'width': 892,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20429323',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 3,
#    'totalpageviews': 362,
#    'accessionyear': 1961,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768154',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:28-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': 'Measurements do not include folded margins on three sides (left: 29 mm; right: 31 mm; bottom: 54 mm).',
#    'medium': 'Graphite on off-white wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'Portrait of Ambroise Vollard',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.8858974358974359,
#      'css3': '#d2b48c'},
#     {'color': '#afafaf',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.06641025641025641,
#      'css3': '#a9a9a9'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.039128205128205126,
#      'css3': '#bc8f8f'},
#     {'color': '#c89664',
#      'spectrum': '#ed7758',
#      'hue': 'Brown',
#      'percent': 0.008564102564102564,
#      'css3': '#bdb76b'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': '1899',
#    'department': 'Department of Drawings',
#    'dateend': 1899,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/296702',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': '1961.152',
#    'labeltext': None,
#    'datebegin': 1899,
#    'culture': 'French',
#    'exhibitioncount': 4,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 296702,
#    'techniqueid': None,
#    'dimensions': 'actual: 45.8 x 39.8 cm (18 1/16 x 15 11/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/296702',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Marian H. Phinney',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-02-26',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 0,
#    'publicationcount': 9,
#    'totaluniquepageviews': 210,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 5,
#    'rank': 85337,
#    'id': 296862,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2007-11-09',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 276286,
#      'idsid': 7759217,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'DDC104701',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104701_dynmc',
#      'alttext': None,
#      'width': 527,
#      'publiccaption': 'recto',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/7759217',
#      'height': 1024},
#     {'date': '2007-11-09',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 276285,
#      'idsid': 7759216,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'DDC104700',
#      'displayorder': 2,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104700_dynmc',
#      'alttext': None,
#      'width': 582,
#      'publiccaption': 'verso',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/7759216',
#      'height': 1024}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 2,
#    'totalpageviews': 282,
#    'accessionyear': 1962,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104701_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:29-0400',
#    'commentary': 'From the same sketchbook (Chappuis II) as Fogg drawing 2003.40.5.',
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': 'Sketchbook page',
#    'medium': 'Graphite on cream wove paper',
#    'lendingpermissionlevel': 0,
#    'title': 'Heads of Mme Cézanne and Louis-Auguste Cézanne; verso: Corner of a Studio',
#    'accessionmethod': 'Bequest',
#    'colors': [{'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.469004329004329,
#      'css3': '#dcdcdc'},
#     {'color': '#c8c8c8',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.38441558441558443,
#      'css3': '#c0c0c0'},
#     {'color': '#afafaf',
#      'spectrum': '#8c5fa8',
#      'hue': 'Grey',
#      'percent': 0.0858008658008658,
#      'css3': '#a9a9a9'},
#     {'color': '#969696',
#      'spectrum': '#8761aa',
#      'hue': 'Grey',
#      'percent': 0.050216450216450215,
#      'css3': '#a9a9a9'},
#     {'color': '#7d7d7d',
#      'spectrum': '#8362aa',
#      'hue': 'Grey',
#      'percent': 0.010562770562770564,
#      'css3': '#808080'}],
#    'provenance': 'Paul Cézanne fils, Paris. [1]  [Paul Guillaume, Paris]. Adrien Chappuis, Tresserve. Otto Wertheimer, Paris. [Fine Arts Associates (Otto Gerson), New York]. Marian H. Phinney, Cambridge, 1955, bequest; to Fogg Art Museum, 1962\r\n\r\n[1] 1936 article by Maurice Raynal, "Dessins de Cézanne." Arts et Métiers graphiques, no. 54 (August 15, 1936), indicates ownership is Cezanne fils.',
#    'groupcount': 0,
#    'dated': 'c. 1877-1881',
#    'department': 'Department of Drawings',
#    'dateend': 1882,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/296862',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': '1962.24',
#    'labeltext': None,
#    'datebegin': 1872,
#    'culture': 'French',
#    'exhibitioncount': 5,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 296862,
#    'techniqueid': None,
#    'dimensions': '21.8 x 12.4 cm (8 9/16 x 4 7/8 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/296862',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Henry P. McIlhenny',
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-03-23',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 1,
#    'publicationcount': 7,
#    'totaluniquepageviews': 428,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 5,
#    'rank': 82900,
#    'id': 297516,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2018-06-26',
#      'copyright': None,
#      'imageid': 488760,
#      'idsid': 446962221,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '767295',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767295',
#      'alttext': None,
#      'width': 2550,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/446962221',
#      'height': 1966},
#     {'date': '2018-06-26',
#      'copyright': None,
#      'imageid': 488761,
#      'idsid': 446962217,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '767296',
#      'displayorder': 2,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767296',
#      'alttext': None,
#      'width': 2550,
#      'publiccaption': 'verso',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/446962217',
#      'height': 1989},
#     {'date': '2018-08-20',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491088,
#      'idsid': 457568568,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768152',
#      'displayorder': 3,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768152',
#      'alttext': None,
#      'width': 2550,
#      'publiccaption': 'recto',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457568568',
#      'height': 1970},
#     {'date': '2018-08-20',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491089,
#      'idsid': 457568564,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768153',
#      'displayorder': 4,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768153',
#      'alttext': None,
#      'width': 2550,
#      'publiccaption': 'verso',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457568564',
#      'height': 1975},
#     {'date': None,
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 135355,
#      'idsid': 43183920,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Ektachrome Professional',
#      'renditionnumber': '80771',
#      'displayorder': 5,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:80771_dynmc',
#      'alttext': None,
#      'width': 1024,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183920',
#      'height': 721}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 5,
#    'totalpageviews': 566,
#    'accessionyear': 1957,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767295',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:32-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Watercolor and graphite on cream wove paper; verso: graphite',
#    'lendingpermissionlevel': 0,
#    'title': 'View of Mont Sainte Victoire; verso: Study of a Tree',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.6233043478260869,
#      'css3': '#d2b48c'},
#     {'color': '#e1c896',
#      'spectrum': '#ed765a',
#      'hue': 'Yellow',
#      'percent': 0.34689855072463766,
#      'css3': '#deb887'},
#     {'color': '#e1e1c8',
#      'spectrum': '#e9715f',
#      'hue': 'Green',
#      'percent': 0.02655072463768116,
#      'css3': '#dcdcdc'},
#     {'color': '#967d64',
#      'spectrum': '#b65590',
#      'hue': 'Brown',
#      'percent': 0.003188405797101449,
#      'css3': '#808080'},
#     {'color': '#7d644b',
#      'spectrum': '#b25593',
#      'hue': 'Yellow',
#      'percent': 5.797101449275362e-05,
#      'css3': '#696969'}],
#    'provenance': 'Rouland.  Bernheim-Jeune, Paris.  Vicomte Bernard d’Hendecourt, Paris, sold; [through Sotheby’s, London, May 9, 1929, lot 165].  Paul Rosenberg, Paris and New York.   Paul J. Sachs, Cambridge, MA (by 1936-1937), sold; [through Jacques Seligmann & Co., New York, November 1937]; to Henry P. McIlhenny, Philadelphia PA (1937-1957), gift; to Fogg Art Museum, 1957.\r\n\r\nNotes:\r\n1. The drawing was listed in the 1936 “Fogg Art Museum, Harvard University, Handbook” (third edition, p. 160) as being in the Paul J. Sachs collection.\r\n2. The drawing is listed as number 6462 in the Jacques Seligmann & Co. stock catalogue from 1937-1938 (Jacques Seligmann & Co. archives, Archives of American Art online). The entry is crossed out,  possibly indicating that the drawing was sold during this time (see note 3).\r\n3. In a night letter dated November 9, 1937 C.M. de Hauke of Jacques Seligmann & Co. notifies Paul J. Sachs that he sold the “Cezanne watercolor” to Henry McIlhenny.  This almost certainly refers to the drawing in question, as Sachs expressed interest in selling the work in correspondence with Seligmann & Co. predating this letter (Jacques Seligmann & Co. archives, Archives of American Art online). In addition, in a memo dated July 17, 1988, Agnes Mongan of the Fogg Art Museum recalls that Paul Sachs had been eager to sell the watercolor. She specifies that the offer to McIlhenny was made with the understanding that he would bequeath the work to the Fogg upon his death.\r\n',
#    'groupcount': 0,
#    'dated': '1885-1887',
#    'department': 'Department of Drawings',
#    'dateend': 1887,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/297516',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': '1957.204',
#    'labeltext': None,
#    'datebegin': 1885,
#    'culture': 'French',
#    'exhibitioncount': 9,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 297516,
#    'techniqueid': None,
#    'dimensions': '38.8 × 49.9 cm (15 1/4 × 19 5/8 in.)\r\nframed: 47.6 × 62.9 cm (18 3/4 × 24 3/4 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/297516',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#   {'copyright': None,
#    'contextualtextcount': 0,
#    'creditline': "Harvard Art Museums/Fogg Museum, Gift of Mr. and Mrs. Justin K. Thannhauser in memory of their son Heinz H. Thannhauser, M.A. '41",
#    'accesslevel': 1,
#    'dateoflastpageview': '2023-04-04',
#    'classificationid': 21,
#    'division': 'European and American Art',
#    'markscount': 1,
#    'publicationcount': 1,
#    'totaluniquepageviews': 539,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'colorcount': 6,
#    'rank': 82100,
#    'id': 297521,
#    'state': None,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'period': None,
#    'images': [{'date': '2004-08-11',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 35630,
#      'idsid': 17825338,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': None,
#      'renditionnumber': '75936',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:75936_dynmc',
#      'alttext': None,
#      'width': 789,
#      'publiccaption': 'recto',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17825338',
#      'height': 1024},
#     {'date': '2018-08-27',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491223,
#      'idsid': 457648402,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768267',
#      'displayorder': 2,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768267',
#      'alttext': None,
#      'width': 1969,
#      'publiccaption': None,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457648402',
#      'height': 2550},
#     {'date': '2018-08-27',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491224,
#      'idsid': 457648406,
#      'format': 'image/jpeg',
#      'description': None,
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768268',
#      'displayorder': 3,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768268',
#      'alttext': None,
#      'width': 1967,
#      'publiccaption': 'verso',
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457648406',
#      'height': 2550}],
#    'worktypes': [{'worktypeid': '128', 'worktype': 'drawing'}],
#    'imagecount': 3,
#    'totalpageviews': 660,
#    'accessionyear': 1955,
#    'standardreferencenumber': None,
#    'signed': None,
#    'classification': 'Drawings',
#    'relatedcount': 0,
#    'verificationlevel': 3,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:75936_dynmc',
#    'titlescount': 1,
#    'peoplecount': 1,
#    'style': None,
#    'lastupdate': '2023-04-08T05:52:32-0400',
#    'commentary': None,
#    'periodid': None,
#    'technique': None,
#    'edition': None,
#    'description': None,
#    'medium': 'Watercolor and graphite on cream wove paper, darkened',
#    'lendingpermissionlevel': 0,
#    'title': 'Study of a Nude Figure',
#    'accessionmethod': 'Gift',
#    'colors': [{'color': '#c8af96',
#      'spectrum': '#e66c64',
#      'hue': 'Brown',
#      'percent': 0.623768115942029,
#      'css3': '#d2b48c'},
#     {'color': '#e1c8af',
#      'spectrum': '#e9715f',
#      'hue': 'Orange',
#      'percent': 0.2802898550724638,
#      'css3': '#f5deb3'},
#     {'color': '#af967d',
#      'spectrum': '#c25687',
#      'hue': 'Brown',
#      'percent': 0.08469565217391305,
#      'css3': '#bc8f8f'},
#     {'color': '#7d7d64',
#      'spectrum': '#6cbd45',
#      'hue': 'Yellow',
#      'percent': 0.010376811594202898,
#      'css3': '#808080'},
#     {'color': '#64644b',
#      'spectrum': '#59ba4a',
#      'hue': 'Green',
#      'percent': 0.0008115942028985507,
#      'css3': '#696969'},
#     {'color': '#4b4b4b',
#      'spectrum': '#3db657',
#      'hue': 'Grey',
#      'percent': 5.797101449275362e-05,
#      'css3': '#2f4f4f'}],
#    'provenance': None,
#    'groupcount': 0,
#    'dated': 'c. 1885',
#    'department': 'Department of Drawings',
#    'dateend': 1890,
#    'people': [{'role': 'Artist',
#      'birthplace': 'Aix-en-Provence',
#      'gender': 'male',
#      'displaydate': '1839 - 1906',
#      'prefix': None,
#      'culture': 'French',
#      'displayname': 'Paul Cézanne',
#      'alphasort': 'Cézanne, Paul',
#      'name': 'Paul Cézanne',
#      'personid': 31681,
#      'deathplace': 'Aix-en-Provence',
#      'displayorder': 1}],
#    'url': 'https://www.harvardartmuseums.org/collections/object/297521',
#    'dateoffirstpageview': '2009-05-23',
#    'century': '19th century',
#    'objectnumber': '1955.47',
#    'labeltext': None,
#    'datebegin': 1880,
#    'culture': 'French',
#    'exhibitioncount': 1,
#    'imagepermissionlevel': 0,
#    'mediacount': 0,
#    'objectid': 297521,
#    'techniqueid': None,
#    'dimensions': '63.5 x 49 cm (25 x 19 5/16 in.)',
#    'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/297521',
#      'type': 'IIIF Manifest',
#      'format': 'application/json',
#      'profile': 'http://iiif.io/api/presentation/2/context.json'}]}]}

# %% [markdown]
# ## Results with Provenance

# %% [markdown]
# The code below will provide you with a dataframe (like an excel file with the artist information)

# %%
artist = "Cezanne"

# %%
def results_provenance(url, df=pd.DataFrame()):
    r = requests.get(url)
    data = r.json()
    info = data['info']
    records = data['records']
    
    # Extract relevant data from each record
    record_data = []
    for record in records:
        record_data.append({
            'title': record['title'],
            'classification': record['classification'],
            'century': record['century'],
            'provenance': record['provenance']
        })
    
    # Append record data to DataFrame
    df = df.append(pd.DataFrame(record_data))
    
    # Recursively call pagination function for next page, if it exists
    if 'next' in info:
        return results_provenance(info['next'], df)
    else:
        return df

# %%
url = f'https://api.harvardartmuseums.org/object?person={artist}&apikey={key}'
df = results_provenance(url)
# Out:
# /tmp/ipykernel_11722/2991405019.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/2991405019.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/2991405019.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/2991405019.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))

# %%
df
# Out:
#                                                title classification  \
# 0  Female Figure Ornamenting a Clock; verso: Frag...       Drawings
# 1  Study of an Ecorché and a Man's Face in Profil...       Drawings
# 2                Sheet of Studies, including a Skull       Drawings
# 3                     Rocky Landscape, after Cézanne       Drawings
# 4                                        Tree Trunks       Drawings
# 5                                    Forest Interior       Drawings
# 6                                  House Among Trees       Drawings
# 7  Portrait of a Man (Emile Zola?); verso: Study ...       Drawings
# 8                                     Study of Trees      Paintings
# 9                         Still Life with Game Birds      Paintings
# 0                                      Old Fisherman       Drawings
# 1                Sketch of Trees; verso: Undergrowth       Drawings
# 2                            Still Life with Commode      Paintings
# 3                                  Large Pine, Study       Drawings
# 4     X-radiograph(s) of "Nature Morte a la Commode"    Photographs
# 5       X-radiograph(s) of "Still Life With Commode"    Photographs
# 6                  X-radiograph(s) of "Jules Peyron"    Photographs
# 7                                      Plaster Cupid       Drawings
# 8  Female Figure Ornamenting a Clock; verso: Frag...       Drawings
# 9  Study of an Ecorché and a Man's Face in Profil...       Drawings
# 0                       Portrait of Ambroise Vollard       Drawings
# 1  Heads of Mme Cézanne and Louis-Auguste Cézanne...       Drawings
# 2  View of Mont Sainte Victoire; verso: Study of ...       Drawings
# 3                             Study of a Nude Figure       Drawings
# 4                                      Old Fisherman       Drawings
# 5                Sketch of Trees; verso: Undergrowth       Drawings
# 6                            Still Life with Commode      Paintings
# 7                                  Large Pine, Study       Drawings
# 8     X-radiograph(s) of "Nature Morte a la Commode"    Photographs
# 9       X-radiograph(s) of "Still Life With Commode"    Photographs
# 0                           Small Houses in Pontoise      Paintings
# 1                                  The Small Bathers         Prints
#
#              century                                         provenance
# 0       19th century  [Ambroise Vollard, Paris]. [New Gallery, New Y...
# 1       19th century  Paul Cézanne fils. [The New Gallery, New York]...
# 2       19th century  [Ambroise Vollard, Paris]. [Waldimir Walter, P...
# 3       20th century  Lewis W. Rubenstein, gift; to Fogg Art Museum,...
# 4       19th century  Paul Cézanne fils, Paris.\r\nPaul Guillaume[?]...
# 5       19th century  Paul Cézanne; his son, Paul Cézanne. [Georges ...
# 6       19th century  [Ambroise Vollard, Paris.] [Marcel Guiot, Pari...
# 7       19th century  Paul Cézanne fils, Paris.\r\nPaul Guillaume, P...
# 8       19th century  [Ambroise Vollard, Paris.] Estate of Ambroise ...
# 9       19th century  Paul Gachet, Auvers, France (c. 1873-1909); to...
# 0  19th-20th century                                               None
# 1       19th century                                               None
# 2       19th century  [Ambroise Vollard, Paris]. [Thannhauser, Munic...
# 3       19th century  [Ambroise Vollard (French, 1867–1939), Paris]....
# 4               None                                               None
# 5               None                                               None
# 6               None                                               None
# 7       19th century  Jenn Thiis, Oslo, sold; to [Galerie Rosengart,...
# 8       19th century  [Ambroise Vollard, Paris]. [New Gallery, New Y...
# 9       19th century  Paul Cézanne fils. [The New Gallery, New York]...
# 0       19th century                                               None
# 1       19th century  Paul Cézanne fils, Paris. [1]  [Paul Guillaume...
# 2       19th century  Rouland.  Bernheim-Jeune, Paris.  Vicomte Bern...
# 3       19th century                                               None
# 4  19th-20th century                                               None
# 5       19th century                                               None
# 6       19th century  [Ambroise Vollard, Paris]. [Thannhauser, Munic...
# 7       19th century  [Ambroise Vollard (French, 1867–1939), Paris]....
# 8               None                                               None
# 9               None                                               None
# 0       19th century  Possibly [Durand-Ruel, Paris and New York], so...
# 1       19th century                                               None

# %% [markdown]
# ## Results with no Provenance

# %%
def results(url, df=pd.DataFrame()):
    r = requests.get(url)
    data = r.json()
    info = data['info']
    records = data['records']
    
    # Extract relevant data from each record
    record_data = []
    for record in records:
        record_data.append({
            'title': record['title'],
            'classification': record['classification'],
            'century': record['century']
        })
    
    # Append record data to DataFrame
    df = df.append(pd.DataFrame(record_data))
    
    # Recursively call pagination function for next page, if it exists
    if 'next' in info:
        return results(info['next'], df)
    else:
        return df

# %%
url = f'https://api.harvardartmuseums.org/object?person={artist}&apikey={key}'
results(url)
# Out:
# /tmp/ipykernel_11722/395679583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/395679583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/395679583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
# /tmp/ipykernel_11722/395679583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(record_data))
#                                                title classification  \
# 0                                  The Small Bathers         Prints
# 1                                         The Artist         Prints
# 2                          Armand Guillaumin, Hanged         Prints
# 3                                  The Large Bathers         Prints
# 4             Mont Sainte-Victoire (recto and verso)       Drawings
# 5                                Head of a Young Boy       Drawings
# 6                       Portrait of Ambroise Vollard       Drawings
# 7  Heads of Mme Cézanne and Louis-Auguste Cézanne...       Drawings
# 8  View of Mont Sainte Victoire; verso: Study of ...       Drawings
# 9                             Study of a Nude Figure       Drawings
# 0                                      Old Fisherman       Drawings
# 1                Sketch of Trees; verso: Undergrowth       Drawings
# 2                            Still Life with Commode      Paintings
# 3                                  Large Pine, Study       Drawings
# 4     X-radiograph(s) of "Nature Morte a la Commode"    Photographs
# 5       X-radiograph(s) of "Still Life With Commode"    Photographs
# 6                  X-radiograph(s) of "Jules Peyron"    Photographs
# 7                                      Plaster Cupid       Drawings
# 8  Female Figure Ornamenting a Clock; verso: Frag...       Drawings
# 9  Study of an Ecorché and a Man's Face in Profil...       Drawings
# 0                Sheet of Studies, including a Skull       Drawings
# 1                     Rocky Landscape, after Cézanne       Drawings
# 2                                        Tree Trunks       Drawings
# 3                                    Forest Interior       Drawings
# 4                                  House Among Trees       Drawings
# 5  Portrait of a Man (Emile Zola?); verso: Study ...       Drawings
# 6                                     Study of Trees      Paintings
# 7                         Still Life with Game Birds      Paintings
# 8                                       Jules Peyron      Paintings
# 9                                      Plaster Cupid      Paintings
# 0                           Small Houses in Pontoise      Paintings
# 1                                  The Small Bathers         Prints
#
#              century
# 0       19th century
# 1  19th-20th century
# 2  19th-20th century
# 3       19th century
# 4       19th century
# 5  19th-20th century
# 6       19th century
# 7       19th century
# 8       19th century
# 9       19th century
# 0  19th-20th century
# 1       19th century
# 2       19th century
# 3       19th century
# 4               None
# 5               None
# 6               None
# 7       19th century
# 8       19th century
# 9       19th century
# 0       19th century
# 1       20th century
# 2       19th century
# 3       19th century
# 4       19th century
# 5       19th century
# 6       19th century
# 7       19th century
# 8       19th century
# 9       19th century
# 0       19th century
# 1       19th century

# %% [markdown]
# ## Download Images

# %% [markdown]
# The function below will download all images for a particular artist, now it could also be that is not only the artist, so we have to do some API research, but that is your job, you need to know what you want to show

# %% [markdown]
# You simply have to modify the artist

# %%
artist = "Cezanne"

# %%
def download_artist_paintings(artist,key):
    # Set up API endpoint and parameters
    endpoint = "https://api.harvardartmuseums.org/object"
    params = {
        "apikey": key,
        "person": artist,
        "classification": "Paintings",
    }

    # Send API request and extract relevant data from JSON response
    response = requests.get(endpoint, params=params)
    if response.status_code == 200:
        data = response.json()["records"]
    else:
        print(f"Error: {response.status_code}")
        data = []

    # Create directory for images if it doesn't exist
    directory_name = artist.lower().replace(' ', '_') + '_paintings'
    if not os.path.exists(directory_name):
        os.makedirs(directory_name)

    # Download and save images
    for record in data:
        object_number = record["objectnumber"]
        image_url = record["primaryimageurl"]
        if image_url:
            response = requests.get(image_url)
            if response.status_code == 200:
                image_data = response.content
                with open(f"{directory_name}/{object_number}.jpg", "wb") as f:
                    f.write(image_data)
                    print(f"Saved image for {object_number}")
            else:
                print(f"Error downloading image for {object_number}")
        else:
            print(f"No image found for {object_number}")

# %%
download_artist_paintings(artist,key)
# Out:
# Saved image for 1998.305
# Saved image for 1976.70
# Saved image for 1961.144
# Saved image for 1964.72
# Saved image for 1934.28
# Saved image for 1951.46
